# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
################### LOADING DATA####################
# defining column names
column_names = [
    "Subject identifier", "Jitter", "Jitter Absolute", "Jitter RAP", "Jitter PPQ5",
    "Jitter DDP", "Shimmer", "Shimmer dB", "Shimmer APQ3", "Shimmer APQ5",
    "Shimmer APQ11", "Shimmer DDA", "Harmonicity NHR_HNR", "Harmonicity NHR",
    "Harmonicity HNR", "Pitch Median", "Pitch Mean", "Pitch Std", "Pitch Min",
    "Pitch Max", "Pulse Number", "Pulse Number of periods", "Pulse Mean period",
    "Pulse Std of period", "Voice Unvoiced frames", "Voice Number of breaks",
    "Voice Degree of breaks", "UPDRS", "PD indicator"
]

data = pd.read_csv('po1_data.txt', header=None, names=column_names)
data
# Out:
#       Subject identifier  Jitter  Jitter Absolute  Jitter RAP  Jitter PPQ5  \
# 0                      1   1.488         0.000090       0.900        0.794
# 1                      1   0.728         0.000038       0.353        0.376
# 2                      1   1.220         0.000074       0.732        0.670
# 3                      1   2.502         0.000123       1.156        1.634
# 4                      1   3.509         0.000167       1.715        1.539
# ...                  ...     ...              ...         ...          ...
# 1035                  40   5.127         0.000398       2.721        2.510
# 1036                  40   1.757         0.000133       0.808        0.690
# 1037                  40   2.912         0.000226       1.141        1.266
# 1038                  40   3.788         0.000275       1.786        1.484
# 1039                  40   1.809         0.000149       0.680        0.843
#
#       Jitter DDP  Shimmer  Shimmer dB  Shimmer APQ3  Shimmer APQ5  ...  \
# 0          2.699    8.334       0.779         4.517         4.609  ...
# 1          1.059    5.864       0.642         2.058         3.180  ...
# 2          2.196    8.719       0.875         4.347         5.166  ...
# 3          3.469   13.513       1.273         5.263         8.771  ...
# 4          5.145    9.112       1.040         3.102         4.927  ...
# ...          ...      ...         ...           ...           ...  ...
# 1035       8.162    9.846       0.965         4.593         6.806  ...
# 1036       2.425    7.571       0.740         2.720         3.927  ...
# 1037       3.423   15.489       1.456         6.433        10.138  ...
# 1038       5.359   15.702       1.367         6.374        11.094  ...
# 1039       2.040    7.881       0.782         2.690         4.543  ...
#
#       Pitch Max  Pulse Number  Pulse Number of periods  Pulse Mean period  \
# 0       187.576           160                      159           0.006065
# 1       234.505           170                      169           0.005181
# 2       211.442          1431                     1427           0.006071
# 3       220.230            94                       92           0.004910
# 4       225.162           117                      114           0.004757
# ...         ...           ...                      ...                ...
# 1035    158.591            63                       60           0.007766
# 1036    143.797            47                       44           0.007561
# 1037    149.641            79                       77           0.007767
# 1038    451.366            75                       70           0.007257
# 1039    137.546            62                       60           0.008211
#
#       Pulse Std of period  Voice Unvoiced frames  Voice Number of breaks  \
# 0                0.000416                  0.000                       0
# 1                0.000403                  2.247                       0
# 2                0.000474                 10.656                       1
# 3                0.000320                  0.000                       0
# 4                0.000380                 18.182                       1
# ...                   ...                    ...                     ...
# 1035             0.001066                 24.194                       2
# 1036             0.000430                 46.053                       1
# 1037             0.000881                 20.000                       1
# 1038             0.001714                 16.667                       3
# 1039             0.000566                 18.182                       1
#
#       Voice Degree of breaks  UPDRS  PD indicator
# 0                      0.000     23             1
# 1                      0.000     23             1
# 2                      0.178     23             1
# 3                      0.000     23             1
# 4                     13.318     23             1
# ...                      ...    ...           ...
# 1035                  15.113      1             0
# 1036                  25.792      1             0
# 1037                   4.574      1             0
# 1038                  19.575      1             0
# 1039                   3.387      1             0
#
# [1040 rows x 29 columns]

# %%
################## Data Preprocessing ###################################
#checking statistics
print(data.describe())

#checking for missing values
print(data.isnull().sum())
# Out:
#        Subject identifier       Jitter  Jitter Absolute   Jitter RAP  \
# count          1040.00000  1040.000000      1040.000000  1040.000000
# mean             20.50000     2.679523         0.000170     1.247053
# std              11.54895     1.765053         0.000106     0.979462
# min               1.00000     0.190000         0.000006     0.062000
# 25%              10.75000     1.507500         0.000095     0.617000
# 50%              20.50000     2.396000         0.000151     1.035500
# 75%              30.25000     3.411500         0.000229     1.602500
# max              40.00000    14.376000         0.000777     8.016000
#
#        Jitter PPQ5   Jitter DDP      Shimmer   Shimmer dB  Shimmer APQ3  \
# count  1040.000000  1040.000000  1040.000000  1040.000000   1040.000000
# mean      1.348327     3.741161    12.918391     1.194895      5.699600
# std       1.138742     2.938443     5.452204     0.420071      3.015183
# min       0.081000     0.185000     1.185000     0.103000      0.496000
# 25%       0.665750     1.851750     9.353500     0.941000      3.703000
# 50%       1.126500     3.107000    12.348500     1.181500      5.134500
# 75%       1.694750     4.808500    15.493250     1.411000      6.942000
# max      13.542000    24.048000    41.137000     2.721000     25.820000
#
#        Shimmer APQ5  ...    Pitch Max  Pulse Number  Pulse Number of periods  \
# count   1040.000000  ...  1040.000000   1040.000000              1040.000000
# mean       7.983552  ...   234.875990    109.744231               105.969231
# std        4.840892  ...   121.541243    150.027703               149.417074
# min        0.708000  ...    85.541000      0.000000                 0.000000
# 25%        5.160250  ...   143.650750     42.750000                40.750000
# 50%        7.050500  ...   195.971000     65.000000                62.000000
# 75%        9.558930  ...   263.798250    113.000000               109.000000
# max       72.860000  ...   597.974000   1490.000000              1489.000000
#
#        Pulse Mean period  Pulse Std of period  Voice Unvoiced frames  \
# count        1040.000000          1040.000000            1040.000000
# mean            0.006547             0.000843              27.682856
# std             0.001875             0.000723              20.975294
# min             0.002039             0.000055               0.000000
# 25%             0.005039             0.000404               8.149250
# 50%             0.006484             0.000644              26.501000
# 75%             0.007923             0.000980              43.064250
# max             0.012070             0.006371              88.158000
#
#        Voice Number of breaks  Voice Degree of breaks        UPDRS  \
# count             1040.000000             1040.000000  1040.000000
# mean                 1.134615               12.370042    13.000000
# std                  1.614764               15.161916    15.894745
# min                  0.000000                0.000000     1.000000
# 25%                  0.000000                0.000000     1.000000
# 50%                  1.000000                5.826000     3.000000
# 75%                  1.000000               22.255500    23.250000
# max                 12.000000               69.117000    55.000000
#
#        PD indicator
# count   1040.000000
# mean       0.500000
# std        0.500241
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 29 columns]
# Subject identifier         0
# Jitter                     0
# Jitter Absolute            0
# Jitter RAP                 0
# Jitter PPQ5                0
# Jitter DDP                 0
# Shimmer                    0
# Shimmer dB                 0
# Shimmer APQ3               0
# Shimmer APQ5               0
# Shimmer APQ11              0
# Shimmer DDA                0
# Harmonicity NHR_HNR        0
# Harmonicity NHR            0
# Harmonicity HNR            0
# Pitch Median               0
# Pitch Mean                 0
# Pitch Std                  0
# Pitch Min                  0
# Pitch Max                  0
# Pulse Number               0
# Pulse Number of periods    0
# Pulse Mean period          0
# Pulse Std of period        0
# Voice Unvoiced frames      0
# Voice Number of breaks     0
# Voice Degree of breaks     0
# UPDRS                      0
# PD indicator               0
# dtype: int64

# %%
####### splitting into two groups, one with Parkinson disease and another with not
ppd_data = data[data['PD indicator'] == 1]
non_ppd_data = data[data['PD indicator'] == 0]

# %%
##### conducting t tests for inferential statistics
significant_features = []

for column in data.columns:
    if column != 'PD indicator':
        t_stat, p_value = stats.ttest_ind(ppd_data[column], non_ppd_data[column])

        # assuming signifcance level of 0.05
        if p_value < 0.05:
            significant_features.append((column, p_value))

# sorting the data by p value so that we can identify the most significant features
sorted_features = sorted(significant_features, key=lambda x: x[1])

for feature, p_value in sorted_features:
    print(f"{feature}: P-value = {p_value}")
# Out:
# Subject identifier: P-value = 3.66025913e-315
# UPDRS: P-value = 1.0259139698689208e-192
# Jitter Absolute: P-value = 6.055252751057853e-08
# Shimmer APQ11: P-value = 2.1507317386375703e-06
# Pitch Max: P-value = 6.418899305637324e-06
# Voice Degree of breaks: P-value = 4.510173397436688e-05
# Voice Unvoiced frames: P-value = 7.95277348097335e-05
# Pitch Std: P-value = 9.068988191270615e-05
# Jitter RAP: P-value = 0.0003292913407710949
# Jitter DDP: P-value = 0.00032952816569233555
# Jitter PPQ5: P-value = 0.0003379936090640013
# Pitch Mean: P-value = 0.000852121912640331
# Jitter: P-value = 0.0016344496445435067
# Pitch Median: P-value = 0.006574901469342033
# Pulse Mean period: P-value = 0.00833933869357909
# Harmonicity NHR_HNR: P-value = 0.008886608396824192
# Voice Number of breaks: P-value = 0.010009929669102151
# Harmonicity NHR: P-value = 0.014127255939245669
# <ipython-input-16-9079e38945d7>:6: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_value = stats.ttest_ind(ppd_data[column], non_ppd_data[column])

# %%
# Features for which we want to create boxplots
selected_features = [
    'Jitter Absolute', 'Shimmer APQ11'
]

# Generate boxplots for each feature
for feature in selected_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='PD indicator', y=feature, data=data)
    plt.title(f'Boxplot of {feature} grouped by PD indicator')
    plt.show()

# %%
correlation_matrix = data.corr()
correlations_with_target = correlation_matrix["PD indicator"].sort_values(ascending=False)

# Exclude 'PD indicator' itself and take top 10 features
top_features = correlations_with_target[1:11]

plt.figure(figsize=(12, 6))
top_features.plot(kind='bar', color='skyblue')
plt.title('Top 10 Features correlated with PD Indicator')
plt.ylabel('Correlation Coefficient')
plt.xlabel('Features')
plt.show()

# %%
#correlation matrix
corr_matrix = data.corr()

#visualizing correlation matrix
plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

#checking corelation of each feature 'PD indicator'
correlations = corr_matrix['PD indicator'].sort_values(ascending=False)
print(correlations)
# Out:
# PD indicator               1.000000
# UPDRS                      0.755330
# Jitter Absolute            0.166999
# Shimmer APQ11              0.146326
# Jitter RAP                 0.111144
# Jitter DDP                 0.111138
# Jitter PPQ5                0.110934
# Jitter                     0.097552
# Pulse Mean period          0.081763
# Harmonicity NHR_HNR        0.081095
# Pulse Number of periods    0.047103
# Pulse Number               0.041038
# Harmonicity HNR            0.040507
# Shimmer dB                 0.027190
# Shimmer                    0.009062
# Shimmer APQ3              -0.018156
# Shimmer DDA               -0.018158
# Shimmer APQ5              -0.022581
# Pulse Std of period       -0.058788
# Pitch Min                 -0.059104
# Harmonicity NHR           -0.076077
# Voice Number of breaks    -0.079831
# Pitch Median              -0.084222
# Pitch Mean                -0.103270
# Pitch Std                 -0.121074
# Voice Unvoiced frames     -0.122044
# Voice Degree of breaks    -0.126151
# Pitch Max                 -0.139398
# Subject identifier        -0.866296
# Name: PD indicator, dtype: float64
